# %%
#Resnet18
import matplotlib.pyplot as plt
train_losses_18 = [0.5036816781702496, 0.21972936637628646,0.19656409499191102,0.1907830688499269,0.19326239781152635]
val_acc_18 = [90.0375,92.5875,93.2875,92.825,93.1625]

# %%
#Resnet34
plt.rcParams['figure.figsize'] = (10,8)
train_losses_34 = [0.42842723822026024,0.1646205101807912,0.13129450657538005,0.12544456390823636,0.12896018520707175]
val_acc_34 = [91.61,94.42,94.72,94.45,94.47]
epochs = [1,2,3,4,5]

# %%
#Resnet50
plt.rcParams['figure.figsize'] = (10,8)
train_losses_50 = [ 0.3972821073645637,0.1314851569873946,0.08664931854038012,0.08787831176249754,0.08580281797122388]
val_acc_50 = [92.25,95.725,95.6,95.525,95.8625]
epochs = [1,2,3,4,5]

# %%
#Resnet101
plt.rcParams['figure.figsize'] = (10,8)
train_losses_101 = [0.385285696495147, 0.1311975818560237,0.08881710045536359,0.08881710045536359,0.08525839233256521]
val_acc_101 = [90.55,95.9625,96.1,96.0625,95.9]
epochs = [1,2,3,4,5]

# %%
#Resnet50_32x4d
plt.rcParams['figure.figsize'] = (10,8)
train_losses_50_32 = [ 0.3572901903901781,0.11256230146686236, 0.08092845539961542, 0.07679698989717733,0.07340107553132942]
val_acc_50_32 = [93.775,95.975,95.975,95.975,96.05]
epochs = [1,2,3,4,5]

# %%
#Resnet152
train_losses_152 = [0.37644113205728075, 0.11683846026091349,0.0771847295675959,0.07314111957432969,0.07314111957432969]
val_acc_152 = [92.8375,96.2625,96.2375,96.4125,96.4125]
epochs = [1,2,3,4,5]

# %%
plt.rcParams['figure.figsize'] = (20,10)
plt.subplot(1,2,1)
plt.plot(epochs,train_losses_18)
plt.plot(epochs,train_losses_34)
plt.plot(epochs,train_losses_50)
plt.plot(epochs,train_losses_101)
plt.plot(epochs,train_losses_50_32)
plt.plot(epochs,train_losses_152)
plt.legend(['Resnet18','Resnet34','Resnet50','Resnet101','Resnext50_32x4d','Resnet152'])
plt.xlabel('epochs')
plt.ylabel('Train_Loss')
plt.title('Train loss vs epochs for different Resnet architectures ')
plt.subplot(1,2,2)
plt.plot(epochs,val_acc_18)
plt.plot(epochs,val_acc_34)
plt.plot(epochs,val_acc_50)
plt.plot(epochs,val_acc_101)
plt.plot(epochs,val_acc_50_32)
plt.plot(epochs,val_acc_152)
plt.legend(['Resnet18','Resnet34','Resnet50','Resnet101','Resnext50_32x4d','Resnet152'])
plt.title('Validation accuracy vs epochs for different Resnet architectures')
plt.xlabel('epochs')
plt.ylabel('Validation_accuracy')
plt.show()

# %%
scores = [94.02,95.62,96.34,96.66,96.57,96.84]
models = ["Resnet18","Resnet34","Resnet50","Resnet101","Resnext50_32x4d","Resnet152"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,8)
sns.barplot(x =models, y = scores)
plt.ylim(90,98)
# Out:
# (90, 98)
